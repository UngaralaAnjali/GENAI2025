# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (6.1.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from plotly) (1.42.1)
# Requirement already satisfied: packaging in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 15)

# %%
sns.countplot(x="alive",data=df)
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(x="age",data=df)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
sns.countplot(x="pclass",data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.boxplot(df["age"])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(df["alive"])
# Out:
# <Axes: ylabel='alive'>

# %%
sns.boxplot(x='class',y='age',data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x="survived",y="fare",data=df)
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.heatmap(df.select_dtypes(include='number').corr(),annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.swarmplot(x="class",y="age",data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>
# c:\Users\DELL\Desktop\june 2025\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.jointplot(data=df,x="age",y="fare")

# %%
g=sns.JointGrid(data=df,x='age',y='fare')
g.plot_joint(sns.scatterplot)
g.plot_marginals(sns.kdeplot)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.pairplot(df[['age','fare']])

# %%
df_numeric=df[['age','fare','pclass']].dropna()
df_numeric.head
# Out:
# <bound method NDFrame.head of       age     fare  pclass
# 0    22.0   7.2500       3
# 1    38.0  71.2833       1
# 2    26.0   7.9250       3
# 3    35.0  53.1000       1
# 4    35.0   8.0500       3
# ..    ...      ...     ...
# 885  39.0  29.1250       3
# 886  27.0  13.0000       2
# 887  19.0  30.0000       1
# 889  26.0  30.0000       1
# 890  32.0   7.7500       3
#
# [714 rows x 3 columns]>

# %%
sns.pairplot(df[['age','fare']])

# %%
df_numeric=df[['age','fare','pclass']].dropna()
df_numeric.head()
# Out:
#     age     fare  pclass
# 0  22.0   7.2500       3
# 1  38.0  71.2833       1
# 2  26.0   7.9250       3
# 3  35.0  53.1000       1
# 4  35.0   8.0500       3

# %%
g=sns.PairGrid(df_numeric)
g.map_diag(sns.histplot,fill=True)
g.map_offdiag(sns.scatterplot)
plt.show()

# %%
g=sns.PairGrid(df_numeric)
g.map_upper(sns.kdeplot,fill=True)
g.map_lower(sns.regplot)
g.map_diag(sns.histplot,fill=True)
plt.show()

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df['sex'].nunique()
# Out:
# 2

# %%
df['pclass'].nunique()
# Out:
# 3

# %%
g=sns.FacetGrid(df,row='sex',col='survived')
g.map(sns.histplot,"age")

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.barplot(x="class",y="fare",data=df,estimator=np.std)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (9.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (4.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (310)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (6.1.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from plotly) (1.42.1)
# Requirement already satisfied: packaging in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
# !pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (0.2.1)
# Collecting kaleido
#   Downloading kaleido-1.0.0-py3-none-any.whl (51 kB)
#                                               0.0/51.5 kB ? eta -:--:--
#      ---------------------------------------- 51.5/51.5 kB 1.3 MB/s eta 0:00:00
# Collecting choreographer>=1.0.5 (from kaleido)
#   Downloading choreographer-1.0.9-py3-none-any.whl (51 kB)
#                                               0.0/51.3 kB ? eta -:--:--
#      ---------------------------------------- 51.3/51.3 kB 2.7 MB/s eta 0:00:00
# Collecting logistro>=1.0.8 (from kaleido)
#   Downloading logistro-1.1.0-py3-none-any.whl (7.9 kB)
# Collecting orjson>=3.10.15 (from kaleido)
#   Downloading orjson-3.10.18-cp311-cp311-win_amd64.whl (134 kB)
#                                               0.0/134.6 kB ? eta -:--:--
#      -------------------------------------- 134.6/134.6 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\dell\desktop\june 2025\.venv\lib\site-packages (from kaleido) (25.0)
# Collecting simplejson>=3.19.3 (from choreographer>=1.0.5->kaleido)
#   Downloading simplejson-3.20.1-cp311-cp311-win_amd64.whl (75 kB)
#                                               0.0/75.6 kB ? eta -:--:--
#      ---------------------------------------- 75.6/75.6 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: simplejson, orjson, logistro, choreographer, kaleido
#   Attempting uninstall: kaleido
#     Found existing installation: kaleido 0.2.1
#     Uninstalling kaleido-0.2.1:
#       Successfully uninstalled kaleido-0.2.1
# Successfully installed choreographer-1.0.9 kaleido-1.0.0 logistro-1.1.0 orjson-3.10.18 simplejson-3.20.1
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
